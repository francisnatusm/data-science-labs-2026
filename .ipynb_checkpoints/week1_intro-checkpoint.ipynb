# %%
print("Hello, Data Science! My name is Natus")
# Out:
# Hello, Data Science! My name is Natus

# %%
import sys
print("Python version:", sys.version)
# Out:
# Python version: 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]
